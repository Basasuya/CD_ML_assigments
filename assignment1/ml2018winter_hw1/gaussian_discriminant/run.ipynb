# %% [markdown]
# # Gaussian Discriminant Analysis and MLE
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the calculation of **gaussian posterior probability** of GDA
# - find appropriate tuples of parameters for variout kinds of **decision boundary**

# %%
# some basic imports
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import math
from plot_ex1 import plot_ex1, figure

# %load_ext autoreload
# %autoreload 2
figure
# Out:
# /home/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ### Decision boundaries are plotted in the figure variable. You may need to refer to it after every plot

# %%
# %matplotlib inline
# Line

mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 = np.array([[2,2]]).T
Sigma1 = np.array([[1, 0], [0, 1]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line', 1)
figure
# Out:
# /home/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
# Line(one side)
mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 = np.array([[2,2]]).T
Sigma1 = np.array([[1, 0], [0, 1]]).T
phi = 0.8

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line (one side)', 2)
figure
# Out:
# /home/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
# Parabalic
mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0.5], [0.5, 1]]).T
mu1 = np.array([[2,2]]).T
Sigma1 = np.array([[1, 0], [0, 1]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Parabalic', 3)
figure
# Out:
# /home/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
# Hyperbola
mu0 = np.array([[-1,-1]]).T
Sigma0 = np.array([[1, 0.8], [0.8, 1]]).T
mu1 = np.array([[0,0]]).T
Sigma1 = np.array([[1, -0.5], [-0.5, 1]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Hyperbola', 4)
figure
# Out:
# /home/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
# two parallel lines
mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 = np.array([[0,0]]).T
Sigma1 = np.array([[1, -0.8], [-0.8, 1]]).T
phi = 0.8

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Two parallel lines.', 5)
figure
# Out:
# /home/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
#circle
mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 = np.array([[0,0]]).T
Sigma1 = np.array([[0.1, 0], [0, 0.1]]).T
phi = 0.8
# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Circle', 6)
figure
# Out:
# /home/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
#Ellipsoid
mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0.5], [0.5, 1]]).T
mu1 = np.array([[2,2]]).T
Sigma1 = np.array([[0.5, 0.25], [0.25, 0.5]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Ellipsoid', 7)
figure
# Out:
# /home/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 = np.array([[0,0]]).T
Sigma1 = np.array([[1, 0], [0, 1]]).T
phi = 0.8


# begin answer
# end answer


plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'No boundary', 8)
figure
# Out:
# /home/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
figure.savefig("hw1_gaussian_discriminant.png")
