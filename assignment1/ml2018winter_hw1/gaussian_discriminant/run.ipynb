# %% [markdown]
# # Gaussian Discriminant Analysis and MLE
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. Please check the pdf file for more details.*
#
# In this exercise you will:
#
# - implement the calculation of **gaussian posterior probability** of GDA
# - find appropriate tuples of parameters for variout kinds of **decision boundary**

# %%
# some basic imports
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import math
from plot_ex1 import plot_ex1, figure

# %load_ext autoreload
# %autoreload 2
figure
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Users/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ### Decision boundaries are plotted in the figure variable. You may need to refer to it after every plot

# %%
# %matplotlib inline
# mu: 2x1 matrix, e.g. np.array([[0,0]]).T
# Sigma: 2x2 matrix e.g. nnp.array([[1, 0], [0, 1]]).T
# phi: a number e.g 0.5

# change the value for specific decision boundary

mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 = np.array([[2,2]]).T
Sigma1 = np.array([[1, 0], [0, 1]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line', 1)
figure
# Out:
# 598230 2 2
# [[0.9345719  0.0654281 ]
#  [0.93437699 0.06562301]
#  [0.93418155 0.06581845]
#  ...
#  [0.09514396 0.90485604]
#  [0.09487027 0.90512973]
#  [0.09459729 0.90540271]]
# /Users/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0], [0, 1]]).T
mu1 = np.array([[2,2]]).T
Sigma1 = np.array([[1, 0], [0, 1]]).T
phi = 0.8

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Line (one side)', 2)
figure
# Out:
# 693054 2 2
# [[0.77551855 0.22448145]
#  [0.77496392 0.22503608]
#  [0.77440832 0.22559168]
#  ...
#  [0.01716804 0.98283196]
#  [0.01711442 0.98288558]
#  [0.01706096 0.98293904]]
# /Users/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
mu0 = np.array([[0,0]]).T
Sigma0 = np.array([[1, 0.5], [0.5, 1]]).T
mu1 = np.array([[2,2]]).T
Sigma1 = np.array([[1, 0], [0, 1]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Parabalic', 3)
figure
# Out:
# /Users/basasuya/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
mu0 = np.array([[-1,-1]]).T
Sigma0 = np.array([[1, 0.5], [0.5, 1]]).T
mu1 = np.array([[1,1]]).T
Sigma1 = np.array([[1, -0.5], [-0.5, 1]]).T
phi = 0.5

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Hyperbola', 4)
figure

# %%
xmu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Two parallel lines.', 5)
figure

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Circle', 6)
figure

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0

# begin answer
# end answer

plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'Ellipsoid', 7)
figure

# %%
mu0 = 0
Sigma0 = 0
mu1 = 0
Sigma1 = 0
phi = 0


# begin answer
# end answer


plot_ex1(mu0, Sigma0, mu1, Sigma1, phi, 'No boundary', 8)
figure

# %%
figure.savefig("hw1_gaussian_discriminant.png")
